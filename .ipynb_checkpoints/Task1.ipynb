# %%
import pandas as pd
import os
content_df=pd.read_csv(r"C:\Users\Aman\Downloads\Content.csv")
reactionTypes_df=pd.read_csv(r"C:\Users\Aman\Downloads\ReactionTypes.csv")
reactions_df=pd.read_csv(r"C:\Users\Aman\Downloads\Reactions.csv")

# %%
def clean_Data(df,output_path):
    df1 = df.drop(df.columns[0], axis=1)
    final_df = df1.dropna()
    final_df.to_csv(output_path,index=False)
    return final_df

def checkDataLength(df):
    df1 = df.drop(df.columns[0], axis=1)
    final_df = df1.dropna(how='any',axis=1)
    return len(final_df)

output_path = output_directory = r"C:\Users\Aman\Documents\folderssss"
file_name1, file_name2, file_name3= "Reactions.csv", "ReactionTypes.csv", "Content.csv"
output_directory1 = os.path.join(output_path,file_name1)
output_directory2 = os.path.join(output_path,file_name2)
output_directory3 = os.path.join(output_path,file_name3)
reactions = clean_Data(reactions_df,output_directory1)
reactionTypes = clean_Data(reactionTypes_df,output_directory2)
content = clean_Data(content_df,output_directory3)

# %%
merged_df = pd.merge(reactions, content, on='Content ID')
# merged_df = pd.merge(merged_df, reactionTypes, on='Type')
merged_df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x      Type_x             Datetime  \
# 0      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 1      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 2      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 3      34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# ...
